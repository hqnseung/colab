# %%
a = 5
b = 3
print(a)
print(a+b)
print(a*b)
# Out:
# 5
# 8
# 15

# %%
a = 1
a -= 2
print(a)
# Out:
# -1

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("현재 온도는 %.1f도 입니다." %15.6)
# Out:
# 현재 온도는 15.6도 입니다.

# %%
print(1==2)
# Out:
# False

# %%
money = int(input("돈을 입력하세요: "))
if money >= 3000:
    print("택시를 타고 가세요.")
else:
    print("걸어가세요.")
# Out:
# 택시를 타고 가세요.

# %%
a = True
b = False

print(a and b)
# Out:
# False

# %%
money = int(input("돈을 입력하세요: "))
hasCreditCard = input("신용카드가 있나요? (yes/no): ")
if money >= 3000 or hasCreditCard == "yes":
    print("택시를 타고 가세요.")
else:
    print("걸어가세요.")
# Out:
# 택시를 타고 가세요.

# %%
time = True
money = 5000
if time == True:
    print("걸어가자")
elif money >= 3000:
    print("택시를 타자")
else:
    print("뛰어가자")
# Out:
# 걸어가자

# %%
num = 0
while num <= 5:
    print(num)
    num += 1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
num = 0
while num <= 10:
    print(num)
    num += 1
    if num == 5:
        break
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
num = 0 
while num < 10:
    num += 1
    if num % 2 == 0:
        continue
    print(num)
# Out:
# 1
# 3
# 5
# 7
# 9
