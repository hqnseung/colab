# %%
def sum (a, b):
    return a + b

sum(1,4)
# Out:
# 5

# %%
def test():
    abc = "test"
    print(abc)

test(abc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16871/1342901068.py in <cell line: 0>()
#       3     print(abc)
#       4
# ----> 5 test(abc)
#
# NameError: name 'abc' is not defined

# %%
def get_pi():
    return 3.14

print(get_pi())
# Out:
# 3.14

# %%
def print_sum(a ,b):
    print(a + b)

print_sum(1, 4)
# Out:
# 5

# %%
def greet():
    print("Hello, World!")  

greet()
# Out:
# Hello, World!

# %%
def sub(a, b):
    return a - b

result = sub(b=3, a=2)
print(result)
# Out:
# -1

# %%
def add_many(*args):
    result = 0
    for i in args:
        result += i
    return result

print(add_many(1, 2, 3, 4, 5))
# Out:
# 15

# %%
def add_mul(choice, *args):
    if choice == "add":
        result = 0
        for i in args:
            result += i
    elif choice == "mul":
        result = 1
        for i in args:
            result *= i
    return result

print(add_mul('add', 1, 2, 3, 4, 5))
print(add_mul('mul', 1, 2, 3, 4, 5))
# Out:
# 15
# 120

# %%
def introduce(name, age, main_lang):
    print("My name is {0}, I'm {1} years old and I use {2}.".format(name, age, main_lang))

introduce("Seungwoo Han", 20, "Typescript")

def print_info(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")

print_info(name="Seungwoo Han", age=20, main_lang="Typescript")
# Out:
# My name is Seungwoo Han, I'm 20 years old and I use Typescript.
# name: Seungwoo Han
# age: 20
# main_lang: Typescript

# %%
def print_order(**kwargs):
    menu = kwargs.get("menu")
    price = kwargs.get("price")
    quantity = kwargs.get("quantity")
    drink = kwargs.get("drink")
    
    for key, value in kwargs.items():
        print(f"{key}: {value}")
    
    if quantity and price:
        print(f"Total price: {price * quantity}")
    if quantity >= 3:
        print("대량 주문 입니다.")

    print("")

print_order(menu="Pizza", quantity=3, drink="Coke")
print_order(menu="Pizza", price=10000, quantity=1, drink="Coke")
print_order(menu="Pizza", price=10000, quantity=3, drink="Coke")
# Out:
# menu: Pizza
# quantity: 3
# drink: Coke
# 대량 주문 입니다.
#
# menu: Pizza
# price: 10000
# quantity: 1
# drink: Coke
# Total price: 10000
#
# menu: Pizza
# price: 10000
# quantity: 3
# drink: Coke
# Total price: 30000
# 대량 주문 입니다.

# %%
def add(a, b):
    print(a + b)

add(1, 2)
# Out:
# 3

# %%
def main(a, b="안녕하세요"):
    print(f"{a}님 {b}")

main("홍길동")
main("홍길동", "반갑습니다")
# Out:
# 홍길동님 안녕하세요
# 홍길동님 반갑습니다

# %%
def power(num, exp = 2):
    print(num ** exp)

power(3)
power(2, 3)
# Out:
# 9
# 8

# %%
def calc(a, b, op):
    if op == "+":
        print(a + b)
    elif op == "-":
        print(a - b)
    elif op == "*":
        print(a * b)
    else:
        print("invalid")

calc(4, 2, "+")
calc(4, 2, "-")
# Out:
# 6
# 2

# %%
def avg_score(**kwargs):
    sum = 0
    for key, value in kwargs.items():
        sum += value
    avg = sum / len(kwargs)
    print(f"Average score: {avg}")

avg_score(math=90, english=80, science=85)
# Out:
# Average score: 85.0

# %%
count = 0
def increase():
    global count
    count += 1
    print(count)

increase()
increase()
increase()
increase()
# Out:
# 1
# 2
# 3
# 4

# %%
def add_many(*args):
    total = 0
    for value in args:
        total += value
    return total

print(add_many(1,2,3,4))
# Out:
# 10

# %%
def ahdmarPtks(str):
    count = 0
    for i in str:
        if i in "aeiou":
            count += 1
    return count

def wkdmarPtks(str):
    count = 0
    for i in str:
        if not i in "aeiou":
            count += 1
    return count

def tnstjwjsghks(str):
    result = ""
    for i in str:
        result = i+result
    return result




print(ahdmarPtks("Hello Python!"))
print(wkdmarPtks("Hello Python!"))
print(tnstjwjsghks("Hello Python!"))
# Out:
# 3
# 10
# !nohtyP olleH
