# %%
width = 50
height = 30
area = width * height
print("The area of the rectangle is:", area)
# Out:
# The area of the rectangle is: 1500

# %%
a = 10
b = 5
print("Before swapping: a =", a, "b =", b)
a, b = b, a
print("After swapping: a =", a, "b =", b)
# Out:
# Before swapping: a = 10 b = 5
# After swapping: a = 5 b = 10

# %%
x = input("Enter first number: ")
y = input("Enter second number: ")
sum = x + y
print("The sum of the two numbers is:", sum)
# Out:
# The sum of the two numbers is: 4050

# %%
x = int(input("Enter first number: "))
y = int(input("Enter second number: "))
sum = x + y
print("The sum of the two numbers is:", sum)
# Out:
# The sum of the two numbers is: 50

# %%
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print("Temperature in Fahrenheit:", fahrenheit, "°F")
# Out:
# Temperature in Fahrenheit: 60.8 °F

# %%
radius = int(input("Enter the radius of the circle: "))
pi = 3.14159
area = pi * (radius ** 2)
circumference = 2 * pi * radius
print("The area of the circle is:", area)
print("The circumference of the circle is:", circumference)
# Out:
# The area of the circle is: 452.38896
# The circumference of the circle is: 75.39815999999999

# %%
r = int(input("Enter a redius: "))
pi = 3.14159
area = pi*r*r
circumference = 2*pi*r
print("Area of the circle is:", area)
print("Circumference of the circle is:", circumference)
# Out:
# Area of the circle is: 12.56636
# Circumference of the circle is: 12.56636

# %%
price = int(input("Enter the price of the item: "))
discount_rate = float(input("Enter the discount rate (as a percentage): "))
total = price - (price * discount_rate / 100)
print("The total price after discount is:", total)
# Out:
# The total price after discount is: 7.5

# %%
msg = 'Merry Christmas!'
len(msg)
# Out:
# 16

# %%
msg = 'Merry Christmas!'
msg.upper()
# Out:
# 'MERRY CHRISTMAS!'

# %%
msg = 'Merry Christmas!'
msg.lower()
# Out:
# 'merry christmas!'

# %%
string = 'python string'
print(string[0], string[4], string[-6], string[-10])
print(string[0:4])
print(string[-10:-4])
print(string[7:])
print(string[:6])
# Out:
# p o s h
# pyth
# hon st
# string
# python

# %%
print('Loque ipsum dolor sit amet, consectetur adipiscing elit.\nSed do eiusmod tempor incididunt ut labore et dolore magna aliqua.')
# Out:
# Loque ipsum dolor sit amet, consectetur adipiscing elit.
# Sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.

# %%
ftemp = int(input("Enter temperature in Fahrenheit: "))
ctemp = (ftemp - 32) * 5/9
print(f"Temperature in Celsius: {ctemp:.2f} °C")
# Out:
# Temperature in Celsius: 37.78 °C

# %%
slist = ['영어', '수학', '사회', '과학']
one2five = [1, 2, 3, 4, 5]

print(slist[0])
# Out:
# 영어

# %%
my_list = [1, 2, 3, 4, 5, 6, 7, 8]
print(my_list[2:5])
print(my_list[:4])
print(my_list[5:])
# Out:
# [3, 4, 5]
# [1, 2, 3, 4]
# [6, 7, 8]

# %%
import random 
print(random.randint(1, 10))
print(random.randrange(1, 10))
my_list = [1, 2, 3, 4, 5]
print(random.choice(my_list))
random.shuffle(my_list)
print(my_list)
# Out:
# 4
# 2
# 5
# [5, 1, 3, 2, 4]

# %%
money = float(input("원금: "))
rate = float(input("이자율: "))
years = int(input("기간: "))

total = money * (1 + rate/100) ** years
print(f"{years}년 후의 원리금: {total:.2f}")
# Out:
# 5년 후의 원리금: 350525315.09

# %%
height = float(input("키(cm): "))
weight = float(input("몸무게(kg): "))
bmi = weight / ((height / 100) ** 2)
print(f"BMI: {bmi:.2f}")
# Out:
# BMI: 22.89

# %%
numberList = [11, 22, 33, 44, 55]
print(numberList)

numberList[0] = 100
print(f'numberList First element changed to 100: {numberList}')

numberList[-1] = 900
print(f'numberList Last element changed to 900: {numberList}')

print(f'Print 22, 33, 44: {numberList[1:4]}')
# Out:
# [11, 22, 33, 44, 55]
# numberList First element changed to 100: [100, 22, 33, 44, 55]
# numberList Last element changed to 900: [100, 22, 33, 44, 900]
# Print 22, 33, 44: [22, 33, 44]

# %%
number1 = random.randint(1, 6)
print(f'First random number: {number1}')
number2 = random.randint(1, 6)
print(f'Second random number: {number2}')

print(f'Sum of the two random numbers: {number1 + number2}')
# Out:
# First random number: 6
# Second random number: 3
# Sum of the two random numbers: 9
