# %%
print("hello world")
# Out:
# hello world

# %%
print(123)
# Out:
# 123

# %%
a = 1
b = 2
print(a+b)
# Out:
# 3

# %%
error test
# Out:
#   File "/tmp/ipykernel_472/2689012796.py", line 1
#     error test
#           ^
# SyntaxError: invalid syntax

# %%
print("abc"+123)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_472/1255769723.py in <cell line: 0>()
# ----> 1 print("abc"+123)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("abc"+"abc")
# Out:
# abcabc

# %%
abc = 123
type(abc)
# Out:
# int
